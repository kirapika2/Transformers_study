# %%
# データセットダウンロード
from datasets import load_dataset

## version 指定ではうまくいかない
## 参考：https://huggingface.co/datasets/abisee/cnn_dailymail/discussions/8#685c546f8ea359b70c884d79
dataset = load_dataset("cnn_dailymail", "3.0.0")
(f"Features: {dataset['train'].column_names}") # ['article', 'highlights', 'id']

# %%
# 中身を確認
sample = dataset["train"][1]
print(f"""
Article (excerpt of 500 characters, total length: {len(sample["article"])}):
{sample["article"][:500]}\n
Summary (length: {len(sample["highlights"])}):
{sample["highlights"]}
""")
